# %%
import numpy as np
import pandas as pd

# %%
ratings = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')

# %%
ratings.drop(['timestamp'], axis=1, inplace=True)
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
ratings.groupby("rating")["rating"].value_counts()
# Out:
# rating
# 0.5     1370
# 1.0     2811
# 1.5     1791
# 2.0     7551
# 2.5     5550
# 3.0    20047
# 3.5    13136
# 4.0    26818
# 4.5     8551
# 5.0    13211
# Name: count, dtype: int64

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ### Combining the Movies and Ratings DataFrame

# %%
df_combined = pd.merge(ratings, movies, on = 'movieId')
df_combined.head()
# Out:
#    userId  movieId  rating             title  \
# 0       1        1     4.0  Toy Story (1995)
# 1       5        1     4.0  Toy Story (1995)
# 2       7        1     4.5  Toy Story (1995)
# 3      15        1     2.5  Toy Story (1995)
# 4      17        1     4.5  Toy Story (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1  Adventure|Animation|Children|Comedy|Fantasy
# 2  Adventure|Animation|Children|Comedy|Fantasy
# 3  Adventure|Animation|Children|Comedy|Fantasy
# 4  Adventure|Animation|Children|Comedy|Fantasy

# %% [markdown]
# Lấy các items có trên 100 ratings.

# %%
groupby_items_Ratings = df_combined.groupby('movieId')['rating']
groupby_items_Ratings = pd.DataFrame(groupby_items_Ratings.count())
item_list_min100_ratings = groupby_items_Ratings[groupby_items_Ratings['rating'] >= 100].index
df_combined_100 =  df_combined[df_combined['movieId'].isin(item_list_min100_ratings)]

# %%
from collections import Counter
# Đếm số lượng mỗi thể loại phim
genre_counts = Counter('|'.join(movies[movies['movieId'].isin(item_list_min100_ratings)]['genres']).split('|'))
# In kết quả
for genre, count in genre_counts.items():
    print(genre, count)
# Out:
# Adventure 49
# Animation 10
# Children 16
# Comedy 41
# Fantasy 18
# Action 58
# Crime 33
# Thriller 45
# Mystery 11
# Sci-Fi 33
# Drama 55
# Romance 24
# War 7
# IMAX 7
# Horror 6
# Musical 4
# Western 1

# %% [markdown]
# ### Create Ratings Matrix

# %%
ratings_matrix = df_combined_100.pivot_table(index = 'userId', columns = 'title', values = 'rating')
ratings_matrix
# Out:
# title   2001: A Space Odyssey (1968)  Ace Ventura: Pet Detective (1994)  \
# userId
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
# 5                                NaN                                3.0
# ...                              ...                                ...
# 606                              5.0                                NaN
# 607                              NaN                                NaN
# 608                              3.0                                3.5
# 609                              NaN                                NaN
# 610                              4.5                                3.0
#
# title   Aladdin (1992)  Alien (1979)  Aliens (1986)  \
# userId
# 1                  NaN           4.0            NaN
# 2                  NaN           NaN            NaN
# 3                  NaN           NaN            NaN
# 4                  4.0           NaN            NaN
# 5                  4.0           NaN            NaN
# ...                ...           ...            ...
# 606                NaN           4.0            3.5
# 607                NaN           3.0            NaN
# 608                3.0           4.0            4.5
# 609                NaN           NaN            NaN
# 610                NaN           4.5            5.0
#
# title   Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 606                                                   4.5
# 607                                                   NaN
# 608                                                   NaN
# 609                                                   NaN
# 610                                                   4.0
#
# title   American Beauty (1999)  American History X (1998)  \
# userId
# 1                          5.0                        5.0
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          5.0                        NaN
# 5                          NaN                        NaN
# ...                        ...                        ...
# 606                        4.5                        4.0
# 607                        3.0                        NaN
# 608                        5.0                        4.0
# 609                        NaN                        NaN
# 610                        3.5                        NaN
#
# title   American Pie (1999)  Apocalypse Now (1979)  ...  \
# userId                                              ...
# 1                       NaN                    4.0  ...
# 2                       NaN                    NaN  ...
# 3                       NaN                    NaN  ...
# 4                       NaN                    NaN  ...
# 5                       NaN                    NaN  ...
# ...                     ...                    ...  ...
# 606                     1.0                    4.5  ...
# 607                     NaN                    NaN  ...
# 608                     2.5                    3.0  ...
# 609                     NaN                    NaN  ...
# 610                     NaN                    5.0  ...
#
# title   Truman Show, The (1998)  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  \
# userId
# 1                           NaN                                        NaN
# 2                           NaN                                        NaN
# 3                           NaN                                        NaN
# 4                           NaN                                        2.0
# 5                           NaN                                        NaN
# ...                         ...                                        ...
# 606                         4.5                                        4.0
# 607                         NaN                                        NaN
# 608                         4.5                                        3.5
# 609                         NaN                                        NaN
# 610                         5.0                                        4.5
#
# title   Twister (1996)  Up (2009)  Usual Suspects, The (1995)  \
# userId
# 1                  3.0        NaN                         5.0
# 2                  NaN        NaN                         NaN
# 3                  NaN        NaN                         NaN
# 4                  NaN        NaN                         NaN
# 5                  NaN        NaN                         4.0
# ...                ...        ...                         ...
# 606                NaN        NaN                         4.5
# 607                5.0        NaN                         NaN
# 608                3.0        NaN                         4.5
# 609                NaN        NaN                         NaN
# 610                NaN        3.5                         4.0
#
# title   V for Vendetta (2006)  WALL·E (2008)  Waterworld (1995)  \
# userId
# 1                         NaN            NaN                NaN
# 2                         NaN            NaN                NaN
# 3                         NaN            NaN                NaN
# 4                         NaN            NaN                NaN
# 5                         NaN            NaN                NaN
# ...                       ...            ...                ...
# 606                       NaN            4.0                NaN
# 607                       NaN            NaN                3.0
# 608                       4.0            NaN                3.0
# 609                       NaN            NaN                3.0
# 610                       3.5            4.5                NaN
#
# title   Willy Wonka & the Chocolate Factory (1971)  X-Men (2000)
# userId
# 1                                              5.0           5.0
# 2                                              NaN           NaN
# 3                                              NaN           NaN
# 4                                              4.0           NaN
# 5                                              NaN           NaN
# ...                                            ...           ...
# 606                                            NaN           NaN
# 607                                            NaN           3.0
# 608                                            3.5           4.0
# 609                                            NaN           NaN
# 610                                            NaN           3.5
#
# [597 rows x 138 columns]

# %% [markdown]
# <a id="there_you_go_3.2"></a>
# ## 1. Memory Based Collaborative Filtering

# %% [markdown]
# ### `User-based Collaborative Filtering`

# %% [markdown]
# Tạo ma trận tương quan Pearson

# %%
user_corr_mat = ratings_matrix.T.corr(min_periods=5)  # nếu số items chung < min_periods=5 thì sim=0
user_corr_mat.head()
# Out:
# userId       1    2    3         4         5         6         7         8    \
# userId
# 1       1.000000  NaN  NaN  0.395182  0.180151 -0.439941 -0.053108  0.464277
# 2            NaN  1.0  NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN  NaN  NaN       NaN       NaN       NaN       NaN       NaN
# 4       0.395182  NaN  NaN  1.000000 -0.394823  0.421927  0.704093  0.055442
# 5       0.180151  NaN  NaN -0.394823  1.000000 -0.006888  0.328889  0.030168
#
# userId  9         10   ...       601       602       603       604       605  \
# userId                 ...
# 1       NaN -0.037987  ...  0.091574  0.254514  0.106031 -0.500000  0.770709
# 2       NaN       NaN  ... -0.583333       NaN       NaN       NaN       NaN
# 3       NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4       NaN  0.541119  ... -0.360844  0.562500  0.196187 -0.158114  0.905206
# 5       NaN       NaN  ...       NaN  0.231642  0.131108  0.068621 -0.245026
#
# userId       606       607       608       609       610
# userId
# 1       0.303854 -0.012077  0.228651 -0.175412  0.071553
# 2       0.583333       NaN       NaN       NaN  0.765641
# 3            NaN       NaN       NaN       NaN       NaN
# 4       0.057797 -0.020659 -0.296370       NaN -0.123595
# 5       0.377341  0.228218  0.263139  0.384111  0.040582
#
# [5 rows x 597 columns]

# %% [markdown]
# Lấy cột 1 của ma trận tương quan và sắp xếp giảm dần, tưc là hệ số tương quan giữa user 1 và các users khác

# %%
corr_user_1 = user_corr_mat.iloc[0]
corr_user_1.sort_values(ascending=False, inplace=True)
corr_user_1
# Out:
# userId
# 1      1.000000
# 511    0.925820
# 366    0.872872
# 90     0.838525
# 430    0.801784
#          ...
# 564         NaN
# 575         NaN
# 583         NaN
# 595         NaN
# 598         NaN
# Name: 1, Length: 597, dtype: float64

# %% [markdown]
# Xem các bộ phim mà user 1 đã đánh giá

# %%
df_combined_100[df_combined_100['userId'] == 1]
# Out:
#        userId  movieId  rating  \
# 0           1        1     4.0
# 267         1        6     4.0
# 369         1       47     5.0
# 572         1       50     5.0
# 854         1      110     4.0
# 1261        1      223     3.0
# 1365        1      231     5.0
# 1568        1      260     5.0
# 1819        1      296     3.0
# 2126        1      316     3.0
# 2316        1      349     4.0
# 2426        1      356     4.0
# 2789        1      367     4.0
# 2998        1      457     5.0
# 3188        1      480     4.0
# 3426        1      500     3.0
# 3570        1      527     5.0
# 3957        1      590     4.0
# 4121        1      592     4.0
# 4310        1      593     4.0
# 4649        1      608     5.0
# 4830        1      648     3.0
# 5094        1      733     4.0
# 5215        1      736     3.0
# 5338        1      780     3.0
# 6008        1     1073     5.0
# 6216        1     1089     5.0
# 6457        1     1097     5.0
# 6641        1     1136     5.0
# 6777        1     1196     5.0
# 6988        1     1197     5.0
# 7130        1     1198     5.0
# 7330        1     1206     5.0
# 7450        1     1208     4.0
# 7557        1     1210     5.0
# 7753        1     1213     5.0
# 7879        1     1214     4.0
# 8192        1     1222     5.0
# 8319        1     1240     5.0
# 8473        1     1258     3.0
# 8582        1     1265     4.0
# 8725        1     1270     5.0
# 9066        1     1291     5.0
# 9457        1     1517     5.0
# 9693        1     1580     3.0
# 10188       1     1732     5.0
# 10778       1     2028     4.0
# 11293       1     2115     5.0
# 11862       1     2329     5.0
# 12642       1     2571     5.0
# 13084       1     2628     4.0
# 13573       1     2716     5.0
# 13849       1     2858     5.0
# 14323       1     2959     5.0
# 15050       1     3147     5.0
# 15656       1     3578     5.0
# 16075       1     3793     5.0
#
#                                                    title  \
# 0                                       Toy Story (1995)
# 267                                          Heat (1995)
# 369                          Seven (a.k.a. Se7en) (1995)
# 572                           Usual Suspects, The (1995)
# 854                                    Braveheart (1995)
# 1261                                       Clerks (1994)
# 1365              Dumb & Dumber (Dumb and Dumber) (1994)
# 1568           Star Wars: Episode IV - A New Hope (1977)
# 1819                                 Pulp Fiction (1994)
# 2126                                     Stargate (1994)
# 2316                     Clear and Present Danger (1994)
# 2426                                 Forrest Gump (1994)
# 2789                                    Mask, The (1994)
# 2998                                Fugitive, The (1993)
# 3188                                Jurassic Park (1993)
# 3426                               Mrs. Doubtfire (1993)
# 3570                             Schindler's List (1993)
# 3957                           Dances with Wolves (1990)
# 4121                                       Batman (1989)
# 4310                    Silence of the Lambs, The (1991)
# 4649                                        Fargo (1996)
# 4830                          Mission: Impossible (1996)
# 5094                                    Rock, The (1996)
# 5215                                      Twister (1996)
# 5338                Independence Day (a.k.a. ID4) (1996)
# 6008          Willy Wonka & the Chocolate Factory (1971)
# 6216                               Reservoir Dogs (1992)
# 6457                   E.T. the Extra-Terrestrial (1982)
# 6641              Monty Python and the Holy Grail (1975)
# 6777   Star Wars: Episode V - The Empire Strikes Back...
# 6988                          Princess Bride, The (1987)
# 7130   Raiders of the Lost Ark (Indiana Jones and the...
# 7330                          Clockwork Orange, A (1971)
# 7450                               Apocalypse Now (1979)
# 7557   Star Wars: Episode VI - Return of the Jedi (1983)
# 7753                                   Goodfellas (1990)
# 7879                                        Alien (1979)
# 8192                            Full Metal Jacket (1987)
# 8319                              Terminator, The (1984)
# 8473                                 Shining, The (1980)
# 8582                                Groundhog Day (1993)
# 8725                           Back to the Future (1985)
# 9066           Indiana Jones and the Last Crusade (1989)
# 9457   Austin Powers: International Man of Mystery (1...
# 9693                    Men in Black (a.k.a. MIB) (1997)
# 10188                           Big Lebowski, The (1998)
# 10778                         Saving Private Ryan (1998)
# 11293        Indiana Jones and the Temple of Doom (1984)
# 11862                          American History X (1998)
# 12642                                 Matrix, The (1999)
# 13084   Star Wars: Episode I - The Phantom Menace (1999)
# 13573         Ghostbusters (a.k.a. Ghost Busters) (1984)
# 13849                             American Beauty (1999)
# 14323                                  Fight Club (1999)
# 15050                             Green Mile, The (1999)
# 15656                                   Gladiator (2000)
# 16075                                       X-Men (2000)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 267                          Action|Crime|Thriller
# 369                               Mystery|Thriller
# 572                         Crime|Mystery|Thriller
# 854                               Action|Drama|War
# 1261                                        Comedy
# 1365                              Adventure|Comedy
# 1568                       Action|Adventure|Sci-Fi
# 1819                   Comedy|Crime|Drama|Thriller
# 2126                       Action|Adventure|Sci-Fi
# 2316                   Action|Crime|Drama|Thriller
# 2426                      Comedy|Drama|Romance|War
# 2789                   Action|Comedy|Crime|Fantasy
# 2998                                      Thriller
# 3188              Action|Adventure|Sci-Fi|Thriller
# 3426                                  Comedy|Drama
# 3570                                     Drama|War
# 3957                       Adventure|Drama|Western
# 4121                         Action|Crime|Thriller
# 4310                         Crime|Horror|Thriller
# 4649                   Comedy|Crime|Drama|Thriller
# 4830             Action|Adventure|Mystery|Thriller
# 5094                     Action|Adventure|Thriller
# 5215             Action|Adventure|Romance|Thriller
# 5338              Action|Adventure|Sci-Fi|Thriller
# 6008               Children|Comedy|Fantasy|Musical
# 6216                        Crime|Mystery|Thriller
# 6457                         Children|Drama|Sci-Fi
# 6641                      Adventure|Comedy|Fantasy
# 6777                       Action|Adventure|Sci-Fi
# 6988       Action|Adventure|Comedy|Fantasy|Romance
# 7130                              Action|Adventure
# 7330                   Crime|Drama|Sci-Fi|Thriller
# 7450                              Action|Drama|War
# 7557                       Action|Adventure|Sci-Fi
# 7753                                   Crime|Drama
# 7879                                 Horror|Sci-Fi
# 8192                                     Drama|War
# 8319                        Action|Sci-Fi|Thriller
# 8473                                        Horror
# 8582                        Comedy|Fantasy|Romance
# 8725                       Adventure|Comedy|Sci-Fi
# 9066                              Action|Adventure
# 9457                       Action|Adventure|Comedy
# 9693                          Action|Comedy|Sci-Fi
# 10188                                 Comedy|Crime
# 10778                             Action|Drama|War
# 11293                     Action|Adventure|Fantasy
# 11862                                  Crime|Drama
# 12642                       Action|Sci-Fi|Thriller
# 13084                      Action|Adventure|Sci-Fi
# 13573                         Action|Comedy|Sci-Fi
# 13849                                Drama|Romance
# 14323                  Action|Crime|Drama|Thriller
# 15050                                  Crime|Drama
# 15656                       Action|Adventure|Drama
# 16075                      Action|Adventure|Sci-Fi

# %% [markdown]
# Ta lấy ví dụ để dự đoán rating của phim có movied là 32 (chưa được rated bở user 1) để thự dự đoán

# %%
print('32nd Movie : ', movies['title'][ movies['movieId'] == 32 ].values)
# Out:
# 32nd Movie :  ['Twelve Monkeys (a.k.a. 12 Monkeys) (1995)']

# %%
# top-k peer group
K=20

# %%
user_peer_group_1_32 = {}

i = 0
for user in corr_user_1.keys():
    rating = df_combined[ (df_combined['userId'] == user) & (df_combined['movieId'] == 32) ]['rating'].sum()
    if  rating:
        i +=1
        user_peer_group_1_32[user] = (corr_user_1[user], rating)
    if i >=K: break   

print(user_peer_group_1_32)
# Out:
# {90: (0.8385254915624212, 4.0), 476: (0.7205766921228922, 4.0), 513: (0.645457935453148, 4.0), 375: (0.6270894413356966, 5.0), 302: (0.6071428571428571, 3.0), 120: (0.5948744389248242, 3.0), 72: (0.5944677716119164, 4.5), 32: (0.5873890337253248, 4.0), 112: (0.5838924858069249, 5.0), 312: (0.5675951758150258, 4.0), 521: (0.5601120336112037, 3.0), 445: (0.5489123137745419, 5.0), 19: (0.5446755607721149, 4.0), 57: (0.5397923479506446, 4.0), 512: (0.5172087743594052, 5.0), 451: (0.5, 5.0), 160: (0.49667154035181316, 5.0), 206: (0.48809353009197637, 3.0), 226: (0.474159243932272, 4.0), 8: (0.4642767787236135, 3.0)}

# %% [markdown]
# Dự đoán rating của user 1 cho bộ phim 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)'

# %%
row_means = ratings_matrix.mean(axis=1)

# %%
def predict_rating(peer_group, target_user):
    sum_similarity = 0
    weighted_ratings = 0
    for user, (sim, rating) in peer_group.items():
        weighted_ratings += sim * (rating - row_means[user])
        sum_similarity += sim

    return weighted_ratings / sum_similarity + row_means[target_user]
    
predict_rating(user_peer_group_1_32, 1)
# Out:
# 4.577054897479311

# %% [markdown]
# ### `Item-based Collaborative Filtering`

# %% [markdown]
# Đưa ma trận ratings về mean-centering với trung bình theo các hàng.

# %%
ratings_matrix_mean_centered = ratings_matrix.sub(row_means, axis=0)
ratings_matrix_mean_centered
# Out:
# title   2001: A Space Odyssey (1968)  Ace Ventura: Pet Detective (1994)  \
# userId
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
# 5                                NaN                          -0.461538
# ...                              ...                                ...
# 606                         1.095745                                NaN
# 607                              NaN                                NaN
# 608                        -0.528689                          -0.028689
# 609                              NaN                                NaN
# 610                         0.087629                          -1.412371
#
# title   Aladdin (1992)  Alien (1979)  Aliens (1986)  \
# userId
# 1                  NaN     -0.403509            NaN
# 2                  NaN           NaN            NaN
# 3                  NaN           NaN            NaN
# 4             0.555556           NaN            NaN
# 5             0.538462           NaN            NaN
# ...                ...           ...            ...
# 606                NaN      0.095745      -0.404255
# 607                NaN     -0.901961            NaN
# 608          -0.528689      0.471311       0.971311
# 609                NaN           NaN            NaN
# 610                NaN      0.087629       0.587629
#
# title   Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 606                                              0.595745
# 607                                                   NaN
# 608                                                   NaN
# 609                                                   NaN
# 610                                             -0.412371
#
# title   American Beauty (1999)  American History X (1998)  \
# userId
# 1                     0.596491                   0.596491
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                     1.555556                        NaN
# 5                          NaN                        NaN
# ...                        ...                        ...
# 606                   0.595745                   0.095745
# 607                  -0.901961                        NaN
# 608                   1.471311                   0.471311
# 609                        NaN                        NaN
# 610                  -0.912371                        NaN
#
# title   American Pie (1999)  Apocalypse Now (1979)  ...  \
# userId                                              ...
# 1                       NaN              -0.403509  ...
# 2                       NaN                    NaN  ...
# 3                       NaN                    NaN  ...
# 4                       NaN                    NaN  ...
# 5                       NaN                    NaN  ...
# ...                     ...                    ...  ...
# 606               -2.904255               0.595745  ...
# 607                     NaN                    NaN  ...
# 608               -1.028689              -0.528689  ...
# 609                     NaN                    NaN  ...
# 610                     NaN               0.587629  ...
#
# title   Truman Show, The (1998)  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  \
# userId
# 1                           NaN                                        NaN
# 2                           NaN                                        NaN
# 3                           NaN                                        NaN
# 4                           NaN                                  -1.444444
# 5                           NaN                                        NaN
# ...                         ...                                        ...
# 606                    0.595745                                   0.095745
# 607                         NaN                                        NaN
# 608                    0.971311                                  -0.028689
# 609                         NaN                                        NaN
# 610                    0.587629                                   0.087629
#
# title   Twister (1996)  Up (2009)  Usual Suspects, The (1995)  \
# userId
# 1            -1.403509        NaN                    0.596491
# 2                  NaN        NaN                         NaN
# 3                  NaN        NaN                         NaN
# 4                  NaN        NaN                         NaN
# 5                  NaN        NaN                    0.538462
# ...                ...        ...                         ...
# 606                NaN        NaN                    0.595745
# 607           1.098039        NaN                         NaN
# 608          -0.528689        NaN                    0.971311
# 609                NaN        NaN                         NaN
# 610                NaN  -0.912371                   -0.412371
#
# title   V for Vendetta (2006)  WALL·E (2008)  Waterworld (1995)  \
# userId
# 1                         NaN            NaN                NaN
# 2                         NaN            NaN                NaN
# 3                         NaN            NaN                NaN
# 4                         NaN            NaN                NaN
# 5                         NaN            NaN                NaN
# ...                       ...            ...                ...
# 606                       NaN       0.095745                NaN
# 607                       NaN            NaN          -0.901961
# 608                  0.471311            NaN          -0.528689
# 609                       NaN            NaN          -0.333333
# 610                 -0.912371       0.087629                NaN
#
# title   Willy Wonka & the Chocolate Factory (1971)  X-Men (2000)
# userId
# 1                                         0.596491      0.596491
# 2                                              NaN           NaN
# 3                                              NaN           NaN
# 4                                         0.555556           NaN
# 5                                              NaN           NaN
# ...                                            ...           ...
# 606                                            NaN           NaN
# 607                                            NaN     -0.901961
# 608                                      -0.028689      0.471311
# 609                                            NaN           NaN
# 610                                            NaN     -0.912371
#
# [597 rows x 138 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

#Thay các giá trị NaN thành 0 để tính toán.
ratings_matrix_mean = ratings_matrix_mean_centered.fillna(0)
# Tính ma trận cosine similarity
cosine_matrix = cosine_similarity(ratings_matrix_mean.T)
# Chuyển ma trận thành DataFrame
item_corr_matrix = pd.DataFrame(cosine_matrix, index=ratings_matrix_mean.columns, columns=ratings_matrix_mean.columns)
item_corr_matrix.head()
# Out:
# title                              2001: A Space Odyssey (1968)  \
# title
# 2001: A Space Odyssey (1968)                           1.000000
# Ace Ventura: Pet Detective (1994)                     -0.014845
# Aladdin (1992)                                         0.001521
# Alien (1979)                                           0.105313
# Aliens (1986)                                          0.101089
#
# title                              Ace Ventura: Pet Detective (1994)  \
# title
# 2001: A Space Odyssey (1968)                               -0.014845
# Ace Ventura: Pet Detective (1994)                           1.000000
# Aladdin (1992)                                              0.025780
# Alien (1979)                                               -0.139801
# Aliens (1986)                                              -0.091529
#
# title                              Aladdin (1992)  Alien (1979)  \
# title
# 2001: A Space Odyssey (1968)             0.001521      0.105313
# Ace Ventura: Pet Detective (1994)        0.025780     -0.139801
# Aladdin (1992)                           1.000000     -0.158970
# Alien (1979)                            -0.158970      1.000000
# Aliens (1986)                           -0.079859      0.457603
#
# title                              Aliens (1986)  \
# title
# 2001: A Space Odyssey (1968)            0.101089
# Ace Ventura: Pet Detective (1994)      -0.091529
# Aladdin (1992)                         -0.079859
# Alien (1979)                            0.457603
# Aliens (1986)                           1.000000
#
# title                              Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)  \
# title
# 2001: A Space Odyssey (1968)                                                0.069858
# Ace Ventura: Pet Detective (1994)                                          -0.182317
# Aladdin (1992)                                                             -0.011985
# Alien (1979)                                                                0.061172
# Aliens (1986)                                                               0.058207
#
# title                              American Beauty (1999)  \
# title
# 2001: A Space Odyssey (1968)                     0.079770
# Ace Ventura: Pet Detective (1994)               -0.070204
# Aladdin (1992)                                  -0.033305
# Alien (1979)                                     0.048994
# Aliens (1986)                                   -0.001458
#
# title                              American History X (1998)  \
# title
# 2001: A Space Odyssey (1968)                        0.013828
# Ace Ventura: Pet Detective (1994)                  -0.135812
# Aladdin (1992)                                      0.015476
# Alien (1979)                                       -0.100824
# Aliens (1986)                                      -0.049714
#
# title                              American Pie (1999)  Apocalypse Now (1979)  \
# title
# 2001: A Space Odyssey (1968)                 -0.066684               0.229947
# Ace Ventura: Pet Detective (1994)             0.095028              -0.019967
# Aladdin (1992)                               -0.002645              -0.083436
# Alien (1979)                                 -0.112016               0.127213
# Aliens (1986)                                -0.086591               0.032714
#
# title                              ...  Truman Show, The (1998)  \
# title                              ...
# 2001: A Space Odyssey (1968)       ...                -0.076424
# Ace Ventura: Pet Detective (1994)  ...                -0.000001
# Aladdin (1992)                     ...                 0.081168
# Alien (1979)                       ...                -0.025498
# Aliens (1986)                      ...                 0.013785
#
# title                              Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  \
# title
# 2001: A Space Odyssey (1968)                                       -0.012274
# Ace Ventura: Pet Detective (1994)                                  -0.107931
# Aladdin (1992)                                                     -0.122079
# Alien (1979)                                                       -0.010685
# Aliens (1986)                                                      -0.037877
#
# title                              Twister (1996)  Up (2009)  \
# title
# 2001: A Space Odyssey (1968)            -0.104741  -0.000862
# Ace Ventura: Pet Detective (1994)        0.144790  -0.020208
# Aladdin (1992)                          -0.015213   0.066249
# Alien (1979)                            -0.046420  -0.145028
# Aliens (1986)                           -0.063590  -0.052891
#
# title                              Usual Suspects, The (1995)  \
# title
# 2001: A Space Odyssey (1968)                         0.044413
# Ace Ventura: Pet Detective (1994)                   -0.149242
# Aladdin (1992)                                      -0.027101
# Alien (1979)                                         0.043808
# Aliens (1986)                                        0.006415
#
# title                              V for Vendetta (2006)  WALL·E (2008)  \
# title
# 2001: A Space Odyssey (1968)                   -0.053646      -0.034517
# Ace Ventura: Pet Detective (1994)              -0.016139      -0.004570
# Aladdin (1992)                                 -0.050094      -0.000563
# Alien (1979)                                    0.027272       0.032279
# Aliens (1986)                                   0.065775       0.015659
#
# title                              Waterworld (1995)  \
# title
# 2001: A Space Odyssey (1968)               -0.091608
# Ace Ventura: Pet Detective (1994)           0.257542
# Aladdin (1992)                             -0.043856
# Alien (1979)                               -0.040057
# Aliens (1986)                              -0.077779
#
# title                              Willy Wonka & the Chocolate Factory (1971)  \
# title
# 2001: A Space Odyssey (1968)                                         0.042026
# Ace Ventura: Pet Detective (1994)                                   -0.010647
# Aladdin (1992)                                                      -0.039654
# Alien (1979)                                                        -0.043623
# Aliens (1986)                                                       -0.030854
#
# title                              X-Men (2000)
# title
# 2001: A Space Odyssey (1968)          -0.121792
# Ace Ventura: Pet Detective (1994)      0.026770
# Aladdin (1992)                        -0.033673
# Alien (1979)                          -0.072927
# Aliens (1986)                         -0.033516
#
# [5 rows x 138 columns]

# %% [markdown]
# Lấy độ tương quan của item 32 với các items và sort

# %%
Monkeys_corr = item_corr_matrix['Twelve Monkeys (a.k.a. 12 Monkeys) (1995)']
Monkeys_corr = Monkeys_corr.sort_values(ascending=False)
Monkeys_corr
# Out:
# title
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)    1.000000
# Pulp Fiction (1994)                          0.195314
# Trainspotting (1996)                         0.157325
# Seven (a.k.a. Se7en) (1995)                  0.151670
# Full Metal Jacket (1987)                     0.150368
#                                                ...
# Batman Forever (1995)                       -0.154539
# GoldenEye (1995)                            -0.161201
# Clear and Present Danger (1994)             -0.162595
# Clueless (1995)                             -0.175387
# Independence Day (a.k.a. ID4) (1996)        -0.181700
# Name: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Length: 138, dtype: float64

# %% [markdown]
# Tìm peer group

# %%
item_peer_group_1_32= {}

i = 0
for item in Monkeys_corr.keys():
    rating = df_combined[ (df_combined['userId'] == 1) & (df_combined['title'] == item) ]['rating'].sum()
    if  rating:
        i +=1
        item_peer_group_1_32[item] = (Monkeys_corr[item], rating)
    if i >=K: break   

print(item_peer_group_1_32)
# Out:
# {'Pulp Fiction (1994)': (0.19531432723044323, 3.0), 'Seven (a.k.a. Se7en) (1995)': (0.15167016979585257, 5.0), 'Full Metal Jacket (1987)': (0.15036830628641462, 5.0), 'Fight Club (1999)': (0.13610940556188864, 5.0), 'Braveheart (1995)': (0.13032640666687617, 4.0), 'Usual Suspects, The (1995)': (0.1076720131666151, 5.0), 'American History X (1998)': (0.08350807813216914, 5.0), 'Big Lebowski, The (1998)': (0.0751322701330421, 5.0), 'Clockwork Orange, A (1971)': (0.06981092388046745, 5.0), 'Monty Python and the Holy Grail (1975)': (0.0607464072428375, 5.0), 'Willy Wonka & the Chocolate Factory (1971)': (0.06044000901798768, 5.0), 'Princess Bride, The (1987)': (0.059763196248658966, 5.0), 'Clerks (1994)': (0.04712099474035346, 3.0), 'Star Wars: Episode VI - Return of the Jedi (1983)': (0.04504566163982933, 5.0), 'Silence of the Lambs, The (1991)': (0.04443339426759507, 4.0), 'Forrest Gump (1994)': (0.04316975698158809, 4.0), 'Goodfellas (1990)': (0.042953155235551724, 5.0), 'Apocalypse Now (1979)': (0.03873977642671799, 4.0), 'Matrix, The (1999)': (0.03572639278959166, 5.0), "Schindler's List (1993)": (0.03439825998639277, 5.0)}

# %%
def predict_rating_item(peer_group, target_item):
    sum_similarity = 0
    weighted_ratings = 0
    for sim, rating in peer_group.values():
        weighted_ratings += sim * rating
        sum_similarity += sim

    return weighted_ratings / sum_similarity
    
predict_rating_item(item_peer_group_1_32, 32)
# Out:
# 4.540115673875433

# %% [markdown]
# *Ở đây hoàn toàn có thể sử dụng chương trình trong phương pháp User-based cho ma trận transpove để thực hiện pp Item-based và cho ra kết quả tương tự.*

# %% [markdown]
# ## `Sử dụng thư viên scikit-surprise`

# %%
from surprise import Reader, Dataset, KNNBasic, SVD, NMF, accuracy, KNNWithMeans
from surprise.model_selection import GridSearchCV, cross_validate, train_test_split

# %% [markdown]
# Tạo dataset của `surpise` từ dataFrame và chia tập train và tập test

# %%
reader = Reader(rating_scale=(0.5, 5.0))
# Load dữ liệu từ pandas
data = Dataset.load_from_df(df_combined_100[['userId', 'movieId', 'rating']], reader = reader )
dataset = data.build_full_trainset()

# %%
# User-based
sim_options = {'name' : 'pearson', 'min_support': 5}
algo_user = KNNWithMeans(k=K, sim_options=sim_options)
algo_user.fit(dataset)

uid = 1
iid = 32 
pre = algo_user.predict(uid, iid, verbose=True)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 1          item: 32         r_ui = None   est = 4.58   {'actual_k': 20, 'was_impossible': False}

# %%
# Item-based
sim_options = {'name' : 'pearson', "user_based": False, 'min_support': 5}
algo_item = KNNWithMeans(k=K, sim_options=sim_options)
algo_item.fit(dataset)

uid = 1
iid = 32 
pre = algo_item.predict(uid, iid, verbose=True)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# user: 1          item: 32         r_ui = None   est = 4.54   {'actual_k': 20, 'was_impossible': False}

# %% [markdown]
# Chia tập train tập test

# %%
from surprise.model_selection import train_test_split
trainset, testset = train_test_split(data, test_size=.25, random_state=10)

# %% [markdown]
# `User-based`

# %%
sim_options = {'name' : 'pearson', 'min_support': 5}
algo_user = KNNWithMeans(k=K, sim_options=sim_options)

# Train the algorithm on the trainset, and predict ratings for the testset
algo_user.fit(trainset)
predictions = algo_user.test(testset)

# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8164
# 0.8163821647966252

# %% [markdown]
# `Item-based`

# %%
sim_options = {'name' : 'pearson', "user_based": False, 'min_support': 5}
algo_item = KNNWithMeans(k=K, sim_options=sim_options)

# Train the algorithm on the trainset, and predict ratings for the testset
algo_item.fit(trainset)

predictions = algo_item.test(testset)
# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8084
# 0.8084497187594657

# %% [markdown]
# ##  Model Based Collaborative Filtering

# %% [markdown]
# ### `SVD`

# %%
algo_SVD = SVD(n_factors=17, random_state=0)

# Train the algorithm on the trainset, and predict ratings for the testset
algo_SVD.fit(trainset)

# Then compute RMSE
predictions = algo_SVD.test(testset)
accuracy.rmse(predictions)

uid = 1
iid = 32
# get a prediction for specific users and items.
pre = algo_SVD.predict(uid, iid, verbose=True)
# Out:
# RMSE: 0.8087
# user: 1          item: 32         r_ui = None   est = 4.47   {'was_impossible': False}

# %% [markdown]
# ### `NMF`

# %%
algo_NMF = NMF(n_factors=17, random_state=0)

# Train the algorithm on the trainset, and predict ratings for the testset
algo_NMF.fit(trainset)

# Then compute RMSE
predictions = algo_NMF.test(testset)
accuracy.rmse(predictions)
uid = 1
iid = 32 
# get a prediction for specific users and items.
pre = algo_NMF.predict(uid, iid, verbose=True)
# Out:
# RMSE: 0.8433
# user: 1          item: 32         r_ui = None   est = 4.49   {'was_impossible': False}

# %% [markdown]
# ## `Recommender System`

# %% [markdown]
# Phần code trên chỉ thử dự đoán rating của một user cho 1 item. Tuy nhiên trong thực tế, phần lớn các doanh nhiệp cần một hệ thống đề xuất các items chứ không phải là dự đoán ratings. Vì vậy ta cần viết các lớp và hàm đề thực hiện việc đó (trong thư viên surprise không hỗ trợ vệ đưa ra top-k users or items).

# %%
#setting up for customized printing
from IPython.display import Markdown, display
def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))
#function to display dataframes side by side    
from IPython.display import display_html
def display_side_by_side(args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline;margin-left:50px !important;margin-right: 40px !important"'),raw=True)

# %%
from collections import defaultdict
# Hàm đưa ra top-k users (items) từ dữ liệu được dự đoán
def get_top_k(predictions, k=10):
    # First map the predictions to each user.
    top_k = defaultdict(list)
    for uid, iid, _, est, _ in predictions:
        top_k[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_k.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_k[uid] = user_ratings[:k]

    return top_k

# %%
# Class xây dựng mô hình collab filtering từ các mô hình trong surprise.
class collab_filtering_based_recommender_model():
    def __init__(self, model, trainset, testset, data):
        self.model = model
        self.trainset = trainset
        self.testset = testset
        self.data = data
        self.pred_test = None
        self.recommendations = None
        self.top_n = None
        self.recommenddf = None

    def fit_and_predict(self):        
        printmd('**Fitting the train data...**', color='blue')
        self.model.fit(self.trainset)       

        printmd('**Predicting the test data...**', color='blue')
        self.pred_test = self.model.test(self.testset)        
        rmse = round(accuracy.rmse(self.pred_test), 3)
        printmd('**RMSE for the predicted result is ' + str(rmse) + '**', color='brown')   
        
        self.top_n = get_top_k(self.pred_test)
        self.recommenddf = pd.DataFrame(columns=['userId', 'movieId', 'rating'])
        for item in self.top_n:
            subdf = pd.DataFrame(self.top_n[item], columns=['movieId', 'rating'])
            subdf['userId'] = item
            cols = subdf.columns.tolist()
            cols = cols[-1:] + cols[:-1]
            subdf = subdf[cols]        
            self.recommenddf = pd.concat([self.recommenddf, subdf], axis = 0)        
        return rmse
        
    def cross_validate(self):
        printmd('**Cross Validating the data...**', color='blue')
        cv_result = cross_validate(self.model, self.data, n_jobs=-1)
        cv_result = round(cv_result['test_rmse'].mean(),3)
        printmd('**Mean CV RMSE is ' + str(cv_result)  + '**', color='brown')
        return cv_result

    def recommend(self, user_id, k=5):
        printmd(f'**Recommending top {k} movies for userid : {user_id} ...**', color='brown')
        
        df = self.recommenddf[self.recommenddf['userId'] == user_id].head(k)
        display(df)
        return df

# %%
from surprise.model_selection import RandomizedSearchCV
# Tìm parameters tốt nhất của model cho tập dữ liệu.
def find_best_model(model, parameters,data):
    clf = RandomizedSearchCV(model, parameters, n_jobs=-1, measures=['rmse'])
    clf.fit(data)             
    print(clf.best_score)
    print(clf.best_params)
    print(clf.best_estimator)
    return clf

# %% [markdown]
# ## Sử dụng các hàm trên để đưa ra đề xuất:

# %% [markdown]
# KNN With Means - Memory Based Collaborative Filtering

# %%
# Tìm parameters tối ưu cho mô hình
sim_options = {
    "name": ["msd", "cosine", "pearson", "pearson_baseline"],
    "min_support": [3, 4, 5],
    "user_based": [False, True],
}
params = { 'k': range(30,50,1), 'sim_options': sim_options}
clf = find_best_model(KNNWithMeans, params, data)
# Out:
# {'rmse': 0.8015085359954147}
# {'rmse': {'k': 40, 'sim_options': {'name': 'pearson', 'min_support': 3, 'user_based': False}}}
# {'rmse': <surprise.prediction_algorithms.knns.KNNWithMeans object at 0x0000015289753A90>}

# %%
# Tạo model collaborative filtering
knnwithmeans = clf.best_estimator['rmse']
col_fil_knnwithmeans = collab_filtering_based_recommender_model(knnwithmeans, trainset, testset, data)

# Fit and Predict
knnwithmeans_rmse = col_fil_knnwithmeans.fit_and_predict()

# cross validate
knnwithmeans_cv_rmse = col_fil_knnwithmeans.cross_validate()
# Out:
# <span style='color:blue'>**Fitting the train data...**</span>
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# <span style='color:blue'>**Predicting the test data...**</span>
# RMSE: 0.8073
# <span style='color:brown'>**RMSE for the predicted result is 0.807**</span>
# <span style='color:blue'>**Cross Validating the data...**</span>
# <span style='color:brown'>**Mean CV RMSE is 0.802**</span>

# %%
# Recommend
result_knn_user1 = col_fil_knnwithmeans.recommend(user_id=10, k=5)
result_knn_user2 = col_fil_knnwithmeans.recommend(user_id=50, k=5)
result_knn_user3 = col_fil_knnwithmeans.recommend(user_id=100, k=5)
# Out:
# <span style='color:brown'>**Recommending top 5 movies for userid : 10 ...**</span>
#   userId movieId    rating
# 0     10     356  3.595843
# 1     10   33794  3.413133
# 2     10    2571  3.272401
# 3     10     588  3.268039
# 4     10    4306  3.053897
# <span style='color:brown'>**Recommending top 5 movies for userid : 50 ...**</span>
#   userId movieId    rating
# 0     50     318  3.635508
# 1     50     296  3.633967
# 2     50    2959  3.491238
# 3     50    1258  3.433256
# 4     50    7438  3.139019
# <span style='color:brown'>**Recommending top 5 movies for userid : 100 ...**</span>
#   userId movieId    rating
# 0    100    1213  4.225142
# 1    100    5989  4.053429
# 2    100    1265  3.985700
# 3    100     648  3.880563
# 4    100    2716  3.815342

# %% [markdown]
# SVD - Model Based Collaborative Filtering

# %%
# Tìm parameters tối ưu cho mô hình
params= {
    "n_factors" :[17],
    "n_epochs": [5, 10, 15, 20],
    "lr_all": [0.002, 0.005],
    "reg_all": [0.4, 0.6]
}
clf = find_best_model(SVD, params, data)
# Out:
# {'rmse': 0.8270181420000817}
# {'rmse': {'n_factors': 17, 'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.4}}
# {'rmse': <surprise.prediction_algorithms.matrix_factorization.SVD object at 0x000001528F4E1250>}

# %%
svd = clf.best_estimator['rmse']
col_fil_svd = collab_filtering_based_recommender_model(svd, trainset, testset, data)

# Fit and Predict
svd_rmse = col_fil_svd.fit_and_predict()
# cross validate
svd_cv_rmse = col_fil_svd.cross_validate()
# Out:
# <span style='color:blue'>**Fitting the train data...**</span>
# <span style='color:blue'>**Predicting the test data...**</span>
# RMSE: 0.8187
# <span style='color:brown'>**RMSE for the predicted result is 0.819**</span>
# <span style='color:blue'>**Cross Validating the data...**</span>
# <span style='color:brown'>**Mean CV RMSE is 0.826**</span>

# %%
# Recommend
result_svd_user1 = col_fil_svd.recommend(user_id=10, k=5)
result_svd_user2 = col_fil_svd.recommend(user_id=50, k=5)
result_svd_user3 = col_fil_svd.recommend(user_id=100, k=5)
# Out:
# <span style='color:brown'>**Recommending top 5 movies for userid : 10 ...**</span>
#   userId movieId    rating
# 0     10    2571  3.711812
# 1     10     356  3.690630
# 2     10     296  3.659183
# 3     10    2858  3.609069
# 4     10   33794  3.451800
# <span style='color:brown'>**Recommending top 5 movies for userid : 50 ...**</span>
#   userId movieId    rating
# 0     50     318  3.743392
# 1     50    2959  3.674140
# 2     50     296  3.568740
# 3     50    1258  3.549464
# 4     50    7438  3.420660
# <span style='color:brown'>**Recommending top 5 movies for userid : 100 ...**</span>
#   userId movieId    rating
# 0    100    1213  4.182664
# 1    100    1265  3.977293
# 2    100    5989  3.949236
# 3    100    2716  3.905758
# 4    100    1968  3.815115

# %% [markdown]
# NMF - Model Based Collaborative Filtering

# %%
# Tìm parameters tối ưu cho mô hình
params= {
    "n_factors" :[17],
    "n_epochs": [5, 10, 15, 20],
    "reg_pu": [0.06, 0.08],
    "lr_bu": [0.005, 0.006]
}
clf = find_best_model(NMF, params, data)
# Out:
# {'rmse': 0.8626445585704372}
# {'rmse': {'n_factors': 17, 'n_epochs': 20, 'reg_pu': 0.08, 'lr_bu': 0.005}}
# {'rmse': <surprise.prediction_algorithms.matrix_factorization.NMF object at 0x000001528F9EDB90>}

# %%
# Tạo model collaborative filtering
NMF = clf.best_estimator['rmse']
col_fil_nmf = collab_filtering_based_recommender_model(NMF, trainset, testset, data)

# Fit and Predict
nmf_rmse = col_fil_nmf.fit_and_predict()
# cross validate
nmf_cv_rmse = col_fil_nmf.cross_validate()
# Out:
# <span style='color:blue'>**Fitting the train data...**</span>
# <span style='color:blue'>**Predicting the test data...**</span>
# RMSE: 0.8685
# <span style='color:brown'>**RMSE for the predicted result is 0.869**</span>
# <span style='color:blue'>**Cross Validating the data...**</span>
# <span style='color:brown'>**Mean CV RMSE is 0.86**</span>

# %%
# Recommend
result_svd_user1 = col_fil_nmf.recommend(user_id= 10, k=5)
result_svd_user2 = col_fil_nmf.recommend(user_id= 50, k=5)
result_svd_user3 = col_fil_nmf.recommend(user_id=100, k=5)
# Out:
# <span style='color:brown'>**Recommending top 5 movies for userid : 10 ...**</span>
#   userId movieId    rating
# 0     10     296  4.076939
# 1     10    2858  3.981808
# 2     10    2571  3.910263
# 3     10   33794  3.483645
# 4     10    4306  3.470316
# <span style='color:brown'>**Recommending top 5 movies for userid : 50 ...**</span>
#   userId movieId    rating
# 0     50    2959  3.997497
# 1     50    1258  3.855093
# 2     50     318  3.848371
# 3     50    7438  3.796323
# 4     50     296  3.454302
# <span style='color:brown'>**Recommending top 5 movies for userid : 100 ...**</span>
#   userId movieId    rating
# 0    100    1265  4.372052
# 1    100    1213  4.249726
# 2    100    2716  4.207357
# 3    100    1968  3.935140
# 4    100     357  3.889634

# %% [markdown]
# Bảng các recomend cho user 10, 50, 100 với các phương pháp khác nhau.

# %% [markdown]
# ![](recommed.png)

# %% [markdown]
# ## So Sánh độ chính xác và thời gian chạy của các mô hình

# %%
from surprise import KNNWithMeans
from surprise import SVD
from surprise import NMF
benchmark = []
# Iterate over all algorithms
models = [KNNWithMeans(sim_options = {'name' : 'pearson', "user_based": False, 'min_support': 5}),
          KNNWithMeans(sim_options = {'name' : 'pearson', 'min_support': 5}),
          SVD(n_factors=19, n_epochs=20, lr_all=0.005, reg_all=0.4),
          NMF(n_factors=19, n_epochs=20, reg_pu=0.005, lr_bu=0.6)]
for i, algorithm in enumerate(models):
    # Perform cross validation
    results = cross_validate(algorithm, data, measures=['RMSE'], cv=5, verbose=False)
    
    # Get results & append algorithm name
    tmp = pd.DataFrame.from_dict(results).mean(axis=0)
    tmp = pd.concat([tmp, pd.Series([str(algorithm).split(' ')[0].split('.')[-1]+"_"+ str(i)], index=['Algorithm'])], axis = 0)      
    benchmark.append(tmp)
    
pd.DataFrame(benchmark).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
#                 test_rmse  fit_time  test_time
# Algorithm
# KNNWithMeans_0   0.801095  0.093338   0.276265
# KNNWithMeans_1   0.813730  0.280931   0.553930
# SVD_2            0.824785  0.093155   0.024065
# NMF_3            1.042966  0.129536   0.033207

# %% [markdown]
# ## References

# %% [markdown]
# - https://www.kaggle.com/code/fuzzywizard/rec-sys-collaborative-filtering-dl-techniques
# - https://www.kaggle.com/code/rangarajansaranathan/collaborative-filtering-based-recommender-system
